# %%
# !git clone https://github.com/pytorch/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 4900, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 4900 (delta 22), reused 20 (delta 20), pack-reused 4871 (from 2)
# Receiving objects: 100% (4900/4900), 41.75 MiB | 7.45 MiB/s, done.
# Resolving deltas: 100% (2414/2414), done.

# %%
# %cd examples/mnist
# Out:
# /content/examples/mnist

# %%
# !python main.py --epochs 1
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.329474
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.425185
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.826558
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.549874
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.467760
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.235351
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.353438
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.344327
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.533725
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.140928
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.174894
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.231632
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 0.173939
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 0.131873
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 0.245199
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.163689
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.527443
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 0.228635
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 0.687668
# ...

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3]             # número de epochs que entrenaste
accuracy = [0.93, 0.97, 0.985] # accuracy obtenido por epoch

plt.plot(epochs, accuracy, marker='o')
plt.title("Accuracy por Epoch – Replicación MNIST")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()
